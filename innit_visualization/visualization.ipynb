# %%
import pandas as pd 

df = pd.read_csv('./clean_data.csv')
df
# Out:
#                         airline airline_code  num_code  dep_time  time_taken  \
# 0               Vietnam Airline          VNA       975  05:45:00          45
# 1               Vietnam Airline          VNA       953  20:40:00          45
# 2               Vietnam Airline          VNA       981  21:40:00          45
# 3               Vietnam Airline          VNA       927  09:30:00          45
# 4               Vietnam Airline          VNA       993  12:50:00          45
# ...                         ...          ...       ...       ...         ...
# 60423               Vietjet Air           VJ       539  17:00:00         120
# 60424           Vietnam Airline          VNA       828  07:00:00         120
# 60425           Vietnam Airline          VNA       832  07:05:00         120
# 60426           Vietnam Airline          VNA       828  07:00:00         120
# 60427  Jetstar Pacific Airlines           BL       305  08:15:00         120
#
#          price Routine departure_time
# ...

# %%
df.describe()
# Out:
#            num_code    time_taken         price
# count  60428.000000  60428.000000  6.042800e+04
# mean    1708.742106     66.858575  1.414121e+06
# std     2294.626096     29.959045  5.884308e+05
# min      101.000000     30.000000  4.329000e+05
# 25%      605.000000     45.000000  1.007100e+06
# 50%      824.000000     60.000000  1.350000e+06
# 75%      981.000000    105.000000  1.757700e+06
# max     9974.000000    120.000000  8.087100e+06

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price'], kde=True, bins=30, color='skyblue')
plt.title("Price Distribution of Flight Tickets")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='airline', y='price', data=df)
plt.title("Price Distribution by Airline")
plt.xlabel("Airline")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='departure_time', y='price', data=df)
plt.title("Impact of Departure Time on Ticket Prices")
plt.xlabel("Departure Time")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show()

# %%
airline_avg_price = df.groupby('airline')['price'].mean()


airline_avg_price.plot(kind='bar', color='skyblue', edgecolor='black')


plt.title('Price vs Airline')
plt.xlabel('Airline')
plt.ylabel('Average Price')


plt.show()

# %%
df['dep_time'] = pd.to_datetime(df['dep_time'], format='%H:%M:%S').dt.hour * 60 + pd.to_datetime(df['dep_time'], format='%H:%M:%S').dt.minute
